# %%
# AI Collaboration Demonstration

**My AI Prompt:**
"[Include the exact prompt - Successfully reads your text file - Displays the file contents clearly - Shows at least TWO pieces of information about your file (choose from): - Number of lines - Number of words - Longest line - First and last lines - Total character count


**What the AI Helped Me With:**
"[Briefly describe how AI assisted you - The AI assisted me because I give some instructions to AI according to my file_path = 'contents/New Text Document.txt' print("--- File Content---)"]"

**What I Learned:**
"[ I learned from the AI how to do code and how to assist the AI]"]

# %%
# Personal Reflection
# My Reflection

**What surprised me about working with files:**
"[The ability to quickly read in a large amount of structured data from a file and process it with a just a few lines of code was suprising to me.
I also found the use of context managers like 'with open(file_path, 'r'') as file'to automatically handle closing the file to a very cleanand powerful way to prevent resources leaks]"

**How this connects to business:**
"[The skill is very essential for any job involving data and analysis or automation.
 For example, in a future job I might to need to write script to automatically process daily transaction logs(CSV or text files) from a databasedump to generate summary reports for management,saving significant manual effort]"

**Next thing I want to learn:**
"[I am curious about Object Oriented Programming specifically how to desgin and implement classes to model real-world entities, as this seems to be a fundamental skill for buliding large,maintainable applications]"
