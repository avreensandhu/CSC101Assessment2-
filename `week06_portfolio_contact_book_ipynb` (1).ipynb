# %%
#A1
Contacts = {
  "Alice" : "0401 765 865",
  "Bob":"0411 987 654" ,
  "Charlie": "0422 555 111"

}
#A2
Contacts["Avreen Kaur"] = "435 461 134"
print (Contacts)
#A3
Contacts["Bob"] ="0411 000 999"
#A4
for name, number in Contacts.items():
  print (f"{name}: {number}")
# Out:
# {'Alice': '0401 765 865', 'Bob': '0411 987 654', 'Charlie': '0422 555 111', 'Avreen Kaur': '435 461 134'}
# Alice: 0401 765 865
# Bob: 0411 000 999
# Charlie: 0422 555 111
# Avreen Kaur: 435 461 134

# %%
#B1
Contacts ={
    "Alice": {"phone": "555- 1234", "email": "alice@example.com"},
    "Bob": {"phone": "555- 5678", "email": "bob@example.com"},
    "Charlie": {"phone": "555- 9012", "email": "charlie@example.com"}
}
#B2
print("--- Contacts List---")
for name, details in Contacts.items():
  phone = details["phone"]
  email = details["email"]
  print(f"{name}: {phone}, {email}")
# Out:
# --- Contacts List---
# Alice: 555- 1234, alice@example.com
# Bob: 555- 5678, bob@example.com
# Charlie: 555- 9012, charlie@example.com
