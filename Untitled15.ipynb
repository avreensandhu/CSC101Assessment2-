# %%
file_path = '/content/New Text Document.txt'

with open(file_path, 'r') as file:
    content = file.read()
    lines = content.splitlines()

print("--- File Content ---")
print(content)
print("\n--- File Information ---")
print(f"Number of lines: {len(lines)}")
print(f"Total character count: {len(content)}")
# Out:
# --- File Content ---
# My favourite cartoon is motu patlu
# Tommy and jerry
# Doremon
# Shinchan
# Chhota bheem
#
#
#
#
#
#
# --- File Information ---
# Number of lines: 9
# Total character count: 85
